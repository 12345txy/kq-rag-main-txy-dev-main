# %%
from dotenv import load_dotenv
from src.build_index_with_cluster import build_topic_tree_from_dir,search_in_topic_tree

from src.build_index_copy import build_index
from lab_1806_vec_db import VecDB
from src.build_index_with_llm import load_topic_tree,save_topic_tree

load_dotenv()

db = VecDB("data")
key = "医院"

# if key not in db.get_all_keys():
# build_index(db, key, "text/RAG/")

# save_topic_tree(topic_tree, "hospital_topic_tree.pkl")
# Out:
# d:\学习资料\科研\rag\kq-rag-main-txy-dev-main\src\build_index_with_cluster.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
from src.rag_complete import rag_complete

stream = rag_complete(
    "医院ICU 成立以来进行的科研项目有几项，发表国家级及省级论文多少篇",
    db,
    key,
    debug=True,
)
start = True

for chunk in stream:
    if start:
        print("==== Result ====")
        start = False
    print(chunk, end="")
# Out:
# ----- streaming request -----
#
# === 处理PDF文件: 1956~2006临床工作一览表.pdf ===
# 已提取PDF: 1956~2006临床工作一览表.pdf，内容长度: 4360 字符
#
# === 处理PDF文件: 1983~2006年手术统计.pdf ===
# 已提取PDF: 1983~2006年手术统计.pdf，内容长度: 2007 字符
#
# === 处理PDF文件: 1998`2006年接受进修.pdf ===
# 已提取PDF: 1998`2006年接受进修.pdf，内容长度: 720 字符
#
# === 处理PDF文件: 2000年～2006年科研项目.pdf ===
# 已提取PDF: 2000年～2006年科研项目.pdf，内容长度: 5458 字符
#
# === 处理PDF文件: 2021.11.17烧伤科：重点学科宣传【6】.pdf ===
# 已提取PDF: 2021.11.17烧伤科：重点学科宣传【6】.pdf，内容长度: 1751 字符
#
# === 处理PDF文件: 98-2006百万元以上设备清单.pdf ===
# 已提取PDF: 98-2006百万元以上设备清单.pdf，内容长度: 1223 字符
#
# === 处理PDF文件: icu介绍.pdf ===
# 已提取PDF: icu介绍.pdf，内容长度: 1424 字符
#
# === 处理PDF文件: 一级期刊.pdf ===
# 已提取PDF: 一级期刊.pdf，内容长度: 5747 字符
#
# === 处理PDF文件: 中医科.pdf ===
# 已提取PDF: 中医科.pdf，内容长度: 692 字符
#
# === 处理PDF文件: 主任医师名录.pdf ===
# 已提取PDF: 主任医师名录.pdf，内容长度: 1981 字符
#
# === 处理PDF文件: 人才队伍建设.pdf ===
# 已提取PDF: 人才队伍建设.pdf，内容长度: 3605 字符
#
# === 处理PDF文件: 保卫科.pdf ===
# 已提取PDF: 保卫科.pdf，内容长度: 681 字符
#
# === 处理PDF文件: 信息管理.pdf ===
# ...
